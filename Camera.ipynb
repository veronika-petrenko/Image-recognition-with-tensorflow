# %%
import cv2
import numpy as np
import os 
import matplotlib.pyplot as plt
import shutil
import pickle

# %%
model = keras.models.load_model('efficientnetb0.h5')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-ac2e52caa04b> in <module>
# ----> 1 model = keras.models.load_model('efficientnetb0.h5')
#
# NameError: name 'keras' is not defined

# %%
cam = cv2.VideoCapture(0)

while True:
    check, frame = cam.read()

    cv2.imshow('video', frame)
    (h, w) = frame.shape[:2]
    face = frame
    face = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)
    face = cv2.resize(face, (500, 500))
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cam.release()
cv2.destroyAllWindows()

# %%
cam.release()
cv2.destroyAllWindows()

# %%
h
# Out:
# 480

# %%
w
# Out:
# 640

# %%
frame.shape
# Out:
# (480, 640, 3)

# %%
face[200]
# Out:
# array([[179, 174, 170],
#        [179, 173, 170],
#        [177, 173, 170],
#        ...,
#        [153, 119, 124],
#        [153, 120, 126],
#        [153, 121, 126]], dtype=uint8)

# %%
face.shape
# Out:
# (500, 500, 3)

# %%
plt.imshow(face)

# %%
cam = cv2.VideoCapture(0)

while True:
    check, frame = cam.read()

    cv2.imshow('video', frame)
    frame = cv2.resize(frame, (500, 500),interpolation = cv2.INTER_AREA)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cam.release()
cv2.destroyAllWindows()

# %%
plt.imshow(frame)

# %%
cv2.imwrite('photo4.jpg',frame)
# Out:
# True
