# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import cv2
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\zhuzh\\OneDrive\\Рабочий стол\\Neoland\\Finalproject\\train1\\152'

# %%
os.chdir('C:\\Users\\zhuzh\\OneDrive\\Рабочий стол\\Neoland\\Finalproject\\train1\\152')

# %%
os.listdir()
# Out:
# ['1520.jpg',
#  '1521.jpg',
#  '15210.jpg',
#  '152100.jpg',
#  '152101.jpg',
#  '152102.jpg',
#  '152103.jpg',
#  '152104.jpg',
#  '152105.jpg',
#  '152106.jpg',
#  '152107.jpg',
#  '152108.jpg',
#  '152109.jpg',
#  '15211.jpg',
#  '152110.jpg',
#  '152111.jpg',
#  '152112.jpg',
#  '152113.jpg',
#  '152114.jpg',
#  '152115.jpg',
#  '152116.jpg',
#  '152117.jpg',
#  '152118.jpg',
#  '152119.jpg',
#  '15212.jpg',
#  '152120.jpg',
#  '152121.jpg',
#  '152123.jpg',
#  '152124.jpg',
#  '152125.jpg',
#  '152126.jpg',
#  '152127.jpg',
#  '152128.jpg',
#  '152129.jpg',
#  '15213.jpg',
#  '152130.jpg',
#  '152131.jpg',
#  '152132.jpg',
#  '152133.jpg',
#  '152134.jpg',
#  '152135.jpg',
#  '152136.jpg',
#  '152137.jpg',
#  '152138.jpg',
#  '152139.jpg',
#  '15214.jpg',
#  '152140.jpg',
#  '152141.jpg',
#  '152142.jpg',
#  '152143.jpg',
#  '152144.jpg',
#  '152145.jpg',
#  '152146.jpg',
#  '152147.jpg',
#  '152148.jpg',
#  '152149.jpg',
#  '15215.jpg',
#  '152150.jpg',
#  '152151.jpg',
# ...

# %%
len(os.listdir())
# Out:
# 757

# %% [markdown]
# # resize 1 image

# %%
img = cv2.imread(r'1524.jpg')
dim = (500,500)
reduccion = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
plt.imshow(reduccion)

# %%
cv2.imwrite('1524.jpg',reduccion)
# Out:
# True

# %%
img2 = cv2.imread('1521.jpg')

# %%
plt.imshow(img2)

# %%
listaim = os.listdir()
listaim
# Out:
# ['1520.jpg',
#  '1521.jpg',
#  '15210.jpg',
#  '152100.jpg',
#  '152101.jpg',
#  '152102.jpg',
#  '152103.jpg',
#  '152104.jpg',
#  '152105.jpg',
#  '152106.jpg',
#  '152107.jpg',
#  '152108.jpg',
#  '152109.jpg',
#  '15211.jpg',
#  '152110.jpg',
#  '152111.jpg',
#  '152112.jpg',
#  '152113.jpg',
#  '152114.jpg',
#  '152115.jpg',
#  '152116.jpg',
#  '152117.jpg',
#  '152118.jpg',
#  '152119.jpg',
#  '15212.jpg',
#  '152120.jpg',
#  '152121.jpg',
#  '152123.jpg',
#  '152124.jpg',
#  '152125.jpg',
#  '152126.jpg',
#  '152127.jpg',
#  '152128.jpg',
#  '152129.jpg',
#  '15213.jpg',
#  '152130.jpg',
#  '152131.jpg',
#  '152132.jpg',
#  '152133.jpg',
#  '152134.jpg',
#  '152135.jpg',
#  '152136.jpg',
#  '152137.jpg',
#  '152138.jpg',
#  '152139.jpg',
#  '15214.jpg',
#  '152140.jpg',
#  '152141.jpg',
#  '152142.jpg',
#  '152143.jpg',
#  '152144.jpg',
#  '152145.jpg',
#  '152146.jpg',
#  '152147.jpg',
#  '152148.jpg',
#  '152149.jpg',
#  '15215.jpg',
#  '152150.jpg',
#  '152151.jpg',
# ...

# %% [markdown]
# # resize one class

# %%
os.chdir('C:\\Users\\zhuzh\\OneDrive\\Рабочий стол\\Neoland\\Finalproject\\train1\\152')
for i in listaim:
    print(i)
    try:
        img = cv2.imread(i) 
        dim = (500,500)
        reduccion = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
        cv2.imwrite(i,reduccion)
    except:
        os.remove(i) #delete image if it is empty because of invalid link
# Out:
# 1520.jpg
# 1521.jpg
# 15210.jpg
# 152100.jpg
# 152101.jpg
# 152102.jpg
# 152103.jpg
# 152104.jpg
# 152105.jpg
# 152106.jpg
# 152107.jpg
# 152108.jpg
# 152109.jpg
# 15211.jpg
# 152110.jpg
# 152111.jpg
# 152112.jpg
# 152113.jpg
# 152114.jpg
# 152115.jpg
# 152116.jpg
# 152117.jpg
# 152118.jpg
# 152119.jpg
# 15212.jpg
# 152120.jpg
# 152121.jpg
# 152123.jpg
# 152124.jpg
# 152125.jpg
# 152126.jpg
# 152127.jpg
# 152128.jpg
# 152129.jpg
# 15213.jpg
# 152130.jpg
# 152131.jpg
# 152132.jpg
# 152133.jpg
# 152134.jpg
# 152135.jpg
# 152136.jpg
# 152137.jpg
# 152138.jpg
# 152139.jpg
# 15214.jpg
# 152140.jpg
# 152141.jpg
# 152142.jpg
# 152143.jpg
# 152144.jpg
# 152145.jpg
# 152146.jpg
# 152147.jpg
# 152148.jpg
# 152149.jpg
# 15215.jpg
# 152150.jpg
# 152151.jpg
# 152152.jpg
# 152153.jpg
# 152154.jpg
# 152155.jpg
# 152156.jpg
# 152157.jpg
# 152158.jpg
# 152159.jpg
# 15216.jpg
# 152160.jpg
# 152161.jpg
# 152162.jpg
# 152163.jpg
# 152164.jpg
# 152165.jpg
# 152166.jpg
# 152167.jpg
# 152168.jpg
# ...

# %%
os.chdir('C:\\Users\\zhuzh\\OneDrive\\Рабочий стол\\Neoland\\Finalproject\\train1\\')

# %%
listadir = ['12647','1310',
 '13332',
 '13876',
 '1472',
 '1602',
 '165',
 '7000',
 '7008']

# %% [markdown]
# # resize train images

# %%
path = 'C:\\Users\\zhuzh\\OneDrive\\Рабочий стол\\Neoland\\Finalproject\\train1\\'
for i in listadir: #landmark ids 
    os.chdir(path + i) #go to the folder with the landmark id 
    listaim = os.listdir() #list with images names
    
    for k in listaim: #go through the images inside the folder
        print(k)
        try:
            img = cv2.imread(k)
            dim = (500,500) #dimensions
            reduccion = cv2.resize(img, dim, interpolation = cv2.INTER_AREA) #resize image
            cv2.imwrite(k,reduccion) #save image
        except:
            os.remove(k) #some images are empty because the link is invalid and we remove them
# Out:
# 126470.jpg
# 126471.jpg
# 1264710.jpg
# 12647100.jpg
# 12647101.jpg
# 12647102.jpg
# 12647103.jpg
# 12647104.jpg
# 12647105.jpg
# 12647106.jpg
# 12647107.jpg
# 12647108.jpg
# 12647109.jpg
# 1264711.jpg
# 12647110.jpg
# 12647111.jpg
# 12647112.jpg
# 12647113.jpg
# 12647114.jpg
# 12647115.jpg
# 12647116.jpg
# 12647117.jpg
# 12647118.jpg
# 12647119.jpg
# 1264712.jpg
# 12647120.jpg
# 12647121.jpg
# 12647122.jpg
# 12647123.jpg
# 12647124.jpg
# 12647125.jpg
# 12647126.jpg
# 12647127.jpg
# 12647128.jpg
# 12647129.jpg
# 1264713.jpg
# 12647130.jpg
# 12647131.jpg
# 12647132.jpg
# 12647133.jpg
# 12647134.jpg
# 12647135.jpg
# 12647136.jpg
# 12647137.jpg
# 12647138.jpg
# 12647139.jpg
# 1264714.jpg
# 12647140.jpg
# 12647141.jpg
# 12647142.jpg
# 12647143.jpg
# 12647144.jpg
# 12647145.jpg
# 12647146.jpg
# 12647147.jpg
# 12647148.jpg
# 12647149.jpg
# 1264715.jpg
# 12647150.jpg
# 12647151.jpg
# 12647152.jpg
# 12647153.jpg
# 12647154.jpg
# 12647155.jpg
# 12647156.jpg
# 12647157.jpg
# 12647158.jpg
# ...

# %% [markdown]
# # resize test images

# %%
os.chdir('C:\\Users\\zhuzh\\OneDrive\\Рабочий стол\\Neoland\\Finalproject\\test1\\')
listadir = os.listdir()
path = 'C:\\Users\\zhuzh\\OneDrive\\Рабочий стол\\Neoland\\Finalproject\\test1\\'

# %%
for i in listadir:
    os.chdir(path + i)
    listaim = os.listdir()
    
    for k in listaim:
        print(k)
        try:
            img = cv2.imread(k)
            dim = (500,500)
            reduccion = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
            cv2.imwrite(k,reduccion)
        except:
            os.remove(k)
# Out:
# 126470.jpg
# 126471.jpg
# 1264710.jpg
# 12647100.jpg
# 12647101.jpg
# 12647102.jpg
# 12647103.jpg
# 12647104.jpg
# 12647105.jpg
# 12647106.jpg
# 12647107.jpg
# 12647108.jpg
# 12647109.jpg
# 1264711.jpg
# 12647110.jpg
# 12647111.jpg
# 12647112.jpg
# 12647113.jpg
# 12647114.jpg
# 12647115.jpg
# 12647116.jpg
# 12647117.jpg
# 12647118.jpg
# 12647119.jpg
# 1264712.jpg
# 12647120.jpg
# 12647121.jpg
# 12647122.jpg
# 12647123.jpg
# 12647124.jpg
# 12647125.jpg
# 12647126.jpg
# 12647127.jpg
# 12647128.jpg
# 12647129.jpg
# 1264713.jpg
# 12647130.jpg
# 12647131.jpg
# 12647132.jpg
# 12647133.jpg
# 12647134.jpg
# 12647135.jpg
# 12647136.jpg
# 12647137.jpg
# 12647138.jpg
# 12647139.jpg
# 1264714.jpg
# 12647140.jpg
# 12647141.jpg
# 12647142.jpg
# 12647143.jpg
# 12647144.jpg
# 12647145.jpg
# 12647146.jpg
# 12647147.jpg
# 12647148.jpg
# 12647149.jpg
# 1264715.jpg
# 12647150.jpg
# 12647151.jpg
# 12647152.jpg
# 12647153.jpg
# 12647154.jpg
# 12647155.jpg
# 12647156.jpg
# 12647157.jpg
# 12647158.jpg
# ...

# %% [markdown]
# # resize validation images

# %%
os.chdir('C:\\Users\\zhuzh\\OneDrive\\Рабочий стол\\Neoland\\Finalproject\\validation1\\')
listadir = os.listdir()
path = 'C:\\Users\\zhuzh\\OneDrive\\Рабочий стол\\Neoland\\Finalproject\\validation1\\'

# %%
for i in listadir:
    os.chdir(path + i)
    listaim = os.listdir()
    
    for k in listaim:
        print(k)
        try:
            img = cv2.imread(k)
            dim = (500,500)
            reduccion = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
            cv2.imwrite(k,reduccion)
        except:
            os.remove(k)
# Out:
# 126470.jpg
# 126471.jpg
# 1264710.jpg
# 1264711.jpg
# 1264712.jpg
# 1264713.jpg
# 1264714.jpg
# 1264715.jpg
# 1264716.jpg
# 1264717.jpg
# 1264718.jpg
# 1264719.jpg
# 126472.jpg
# 1264720.jpg
# 1264721.jpg
# 1264722.jpg
# 1264723.jpg
# 1264724.jpg
# 1264725.jpg
# 1264726.jpg
# 1264727.jpg
# 1264728.jpg
# 1264729.jpg
# 126473.jpg
# 1264730.jpg
# 1264731.jpg
# 1264732.jpg
# 1264733.jpg
# 1264734.jpg
# 1264735.jpg
# 1264736.jpg
# 1264737.jpg
# 1264738.jpg
# 1264739.jpg
# 126474.jpg
# 1264740.jpg
# 1264741.jpg
# 1264742.jpg
# 1264743.jpg
# 1264744.jpg
# 1264745.jpg
# 1264746.jpg
# 1264747.jpg
# 1264748.jpg
# 1264749.jpg
# 126475.jpg
# 1264750.jpg
# 1264751.jpg
# 1264752.jpg
# 1264753.jpg
# 1264754.jpg
# 1264755.jpg
# 1264756.jpg
# 1264757.jpg
# 1264758.jpg
# 1264759.jpg
# 126476.jpg
# 1264760.jpg
# 1264761.jpg
# 126477.jpg
# 126478.jpg
# 126479.jpg
# 13100.jpg
# 13101.jpg
# 131010.jpg
# 131011.jpg
# 131012.jpg
# 131013.jpg
# 131014.jpg
# 131015.jpg
# 131016.jpg
# 131017.jpg
# 131018.jpg
# ...
